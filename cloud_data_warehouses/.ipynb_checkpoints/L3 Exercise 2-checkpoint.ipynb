# %% [markdown]
# # Exercise 2: Creating Redshift Cluster using the AWS python SDK
# ## An example of Infrastructure-as-code

# %%
import pandas as pd
import boto3
import json

# %% [markdown]
# # STEP 0: Make sure you have an AWS secret and access key
#
# - Create a new IAM user in your AWS account
# - Give it `AdministratorAccess`, From `Attach existing policies directly` Tab
# - Take note of the access key and secret
# - Edit the file `dwh.cfg` in the same folder as this notebook and fill
# <font color='red'>
# <BR>
# [AWS]<BR>
# KEY= YOUR_AWS_KEY<BR>
# SECRET= YOUR_AWS_SECRET<BR>
# <font/>

# %% [markdown]
# # Load DWH Params from a file

# %%
import configparser
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY                    = config.get('AWS','KEY')
SECRET                 = config.get('AWS','SECRET')

DWH_CLUSTER_TYPE       = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("DWH","DWH_DB")
DWH_DB_USER            = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD        = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT               = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)

pd.DataFrame({"Param":
                  ["DWH_CLUSTER_TYPE", "DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER", "DWH_DB_PASSWORD", "DWH_PORT", "DWH_IAM_ROLE_NAME"],
              "Value":
                  [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT, DWH_IAM_ROLE_NAME]
             })
# Out:
#                     Param       Value
# 0        DWH_CLUSTER_TYPE  multi-node
# 1           DWH_NUM_NODES           4
# 2           DWH_NODE_TYPE   dc2.large
# 3  DWH_CLUSTER_IDENTIFIER  dwhCluster
# 4                  DWH_DB         dwh
# 5             DWH_DB_USER     dwhuser
# 6         DWH_DB_PASSWORD    Passw0rd
# 7                DWH_PORT        5439
# 8       DWH_IAM_ROLE_NAME     dwhRole

# %% [markdown]
# ## Create clients for EC2, S3, IAM, and Redshift

# %%
ec2 = boto3.client(
    "ec2",
    region_name="us-west-2",
    aws_access_key_id=KEY,
    aws_secret_access_key=SECRET
)

s3 = boto3.client(
    "s3",
    region_name="us-west-2",
    aws_access_key_id=KEY,
    aws_secret_access_key=SECRET
)

iam = boto3.client(
    "iam",
    region_name="us-west-2",
    aws_access_key_id=KEY,
    aws_secret_access_key=SECRET
)

redshift = boto3.client(
    "redshift",
    region_name="us-west-2",
    aws_access_key_id=KEY,
    aws_secret_access_key=SECRET
)

# %% [markdown]
# ## Check out the sample data sources on S3

# %%
for obj in s3.list_objects(Bucket="awssampledbuswest2", Prefix="ssbgz/")["Contents"]:
    print(obj["Key"])
# Out:
# ssbgz/
# ssbgz/customer0002_part_00.gz
# ssbgz/dwdate.tbl.gz
# ssbgz/lineorder0000_part_00.gz
# ssbgz/lineorder0001_part_00.gz
# ssbgz/lineorder0002_part_00.gz
# ssbgz/lineorder0003_part_00.gz
# ssbgz/lineorder0004_part_00.gz
# ssbgz/lineorder0005_part_00.gz
# ssbgz/lineorder0006_part_00.gz
# ssbgz/lineorder0007_part_00.gz
# ssbgz/part0000_part_00.gz
# ssbgz/part0001_part_00.gz
# ssbgz/part0002_part_00.gz
# ssbgz/part0003_part_00.gz
# ssbgz/supplier.tbl_0000_part_00.gz
# ssbgz/supplier0001_part_00.gz
# ssbgz/supplier0002_part_00.gz
# ssbgz/supplier0003_part_00.gz

# %% [markdown]
# ## STEP 1: IAM ROLE
# - Create an IAM Role that makes Redshift able to access S3 bucket (ReadOnly)

# %%
assume_role_doc = json.dumps({
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Principal": {
                "Service": "redshift.amazonaws.com"
            },
            "Action": "sts:AssumeRole"
        }
    ]
})

dwhRole = iam.create_role(
    RoleName=DWH_IAM_ROLE_NAME,
    Description="Allow redshift to read from S3 Bucket",
    AssumeRolePolicyDocument=assume_role_doc
)

iam.attach_role_policy(
    PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess",
    RoleName=DWH_IAM_ROLE_NAME
)

# Copied from AWS Console
## https://console.aws.amazon.com/iam/home?region=us-west-1#/policies/arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess$serviceLevelSummary
## arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess
# Out:
# {'ResponseMetadata': {'RequestId': 'd7f6d7ac-eb67-41ba-83c4-f85210ef0d68',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd7f6d7ac-eb67-41ba-83c4-f85210ef0d68',
#    'content-type': 'text/xml',
#    'content-length': '212',
#    'date': 'Wed, 06 May 2020 02:50:15 GMT'},
#   'RetryAttempts': 0}}

# %%
roleArn = iam.get_role(
    RoleName=DWH_IAM_ROLE_NAME 
)["Role"]["Arn"]

# %% [markdown]
# ## STEP 2:  Redshift Cluster
#
# - Create a RedShift Cluster
# - For complete arguments to `create_cluster`, see [docs](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/redshift.html#Redshift.Client.create_cluster)

# %%
response = redshift.create_cluster(
    # add parameters for hardware
    DBName=DWH_DB,
    ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
    ClusterType=DWH_CLUSTER_TYPE,
    NodeType=DWH_NODE_TYPE,
    NumberOfNodes=int(DWH_NUM_NODES),
    # add parameters for identifiers & credentials
    MasterUsername=DWH_DB_USER,
    MasterUserPassword=DWH_DB_PASSWORD,
    # add parameter for role (to allow s3 access)
    IamRoles=[
      roleArn
    ]
)

# %% [markdown]
# ## 2.1 *Describe* the cluster to see its status
# - run this block several times until the cluster status becomes `Available`

# %%
metadata_of_interest = [
    "ClusterIdentifier",
    "NodeType",
    "ClusterStatus",
    "MasterUsername",
    "DBName",
    "Endpoint",
    "NumberOfNodes",
    "VpcId"
]

describe_dict = redshift.describe_clusters(
    ClusterIdentifier=DWH_CLUSTER_IDENTIFIER
)["Clusters"][0]

{k: v for (k, v) in describe_dict.items() if k in metadata_of_interest}
# Out:
# {'ClusterIdentifier': 'dwhcluster',
#  'NodeType': 'dc2.large',
#  'ClusterStatus': 'available',
#  'MasterUsername': 'dwhuser',
#  'DBName': 'dwh',
#  'Endpoint': {'Address': 'dwhcluster.ctcwpuiwdyvj.us-west-2.redshift.amazonaws.com',
#   'Port': 5439},
#  'VpcId': 'vpc-65761a1d',
#  'NumberOfNodes': 4}

# %%
print("DWH_ENDPOINT: ", describe_dict["Endpoint"]["Address"])
print("DWH_ROLE_ARN: ", describe_dict["IamRoles"][0]["IamRoleArn"])
print("Role ARN: ", roleArn)

DWH_ENDPOINT = describe_dict["Endpoint"]["Address"]
DWH_ROLE_ARN = describe_dict["IamRoles"][0]["IamRoleArn"]
# Out:
# DWH_ENDPOINT:  dwhcluster.ctcwpuiwdyvj.us-west-2.redshift.amazonaws.com
# DWH_ROLE_ARN:  arn:aws:iam::702717750718:role/dwhRole
# Role ARN:  arn:aws:iam::702717750718:role/dwhRole

# %% [markdown]
# <h2> 2.2 Take note of the cluster <font color='red'> endpoint and role ARN </font> </h2>

# %% [markdown]
# <font color='red'>DO NOT RUN THIS unless the cluster status becomes "Available" </font>

# %% [markdown]
# ## STEP 3: Open an incoming  TCP port to access the cluster ednpoint

# %%
defaultSg = ec2.describe_security_groups(
    GroupNames=["default"]
)["SecurityGroups"][0]["GroupId"]


## https://us-west-1.console.aws.amazon.com/ec2/home?region=us-west-1#SecurityGroup:group-id=sg-2d57a950
responseSg = ec2.authorize_security_group_ingress(
    IpProtocol="TCP",
    CidrIp="0.0.0.0/0",
    FromPort=int(DWH_PORT),
    ToPort=int(DWH_PORT),
    GroupId=defaultSg
#     GroupName="defaultSg"
)

# %% [markdown]
# ## STEP 4: Make sure you can connect to the clusterConnect to the cluster

# %%
# %load_ext sql

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://dwhuser:Passw0rd@dwhcluster.ctcwpuiwdyvj.us-west-2.redshift.amazonaws.com:5439/dwh

# %%
# %%sql
#
# SELECT *
# FROM information_schema.tables
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctcwpuiwdyvj.us-west-2.redshift.amazonaws.com:5439/dwh
# 281 rows affected.
# [('dwh', 'pg_catalog', 'svcs_stream_segs', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_query_summary', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_unload_log', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_user_info', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_database_info', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_class_info', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_proc_info', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_attribute_info', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_s3log', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_s3partition_summary', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_s3query_summary', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_s3requests', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_s3retries', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_plan_info', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_s3list', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_alert_event_log', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_default_acl', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_compile', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_concurrency_scaling_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svcs_explain', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_conf', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_schema_quota_state', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_table_info', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_columns', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_library', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_interleaved_columns', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_sem_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_sem_usage_leader', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_restore_table_state', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_transactions', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_vacuum_progress', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_shdepend', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_vacuum_summary', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_vacuum_percentage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_user_info', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_s3partition_summary', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statistic_indicator', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_s3requests', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_s3retries', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_stored_proc_call', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_stored_proc_messages', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_terminate', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_external_columns', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_external_databases', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_external_partitions', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_external_schemas', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_external_tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_query_metrics_summary', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_query_queue_info', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_udf_log', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_s3catalog', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_s3query', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_s3query_summary', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_s3list', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_s3log', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_s3partition', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_query_report', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_query_state', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_query_summary', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_statementtext', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_awsclient_error', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_compile', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_federated_query', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_mv_refresh_status', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_query_metrics', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_external_schema', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_xrestore', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'systable_globaldict', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'systable_topology', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'systable_schema', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'padb_config_harvest', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_diskusage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svl_qlog', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'svv_query_inflight', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_tombstone', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_schema_quota_violations', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_mv_info', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_usage_control', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_incremental_resize_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_commit_internal_stats', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_prefetch_stats', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statistic', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_rlf_scan', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_mv_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_column_stats', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_settings', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_type', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_attribute', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_class', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_tablespace', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_inherits', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_index', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_operator', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_opclass', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_am', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_amop', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_amproc', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_language', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_largeobject', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_aggregate', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statistic_multicol', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_trigger', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_listener', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_cast', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_namespace', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_conversion', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_udf', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_bar_repos', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_bar_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_depend', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_highwatermark', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_resize', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_attrdef', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_constraint', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_database', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_description', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_group', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_proc', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_rewrite', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_bar_ddllog', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_user', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_rules', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_views', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_table_def', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_indexes', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_stats', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_stat_all_tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_stat_sys_tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_stat_user_tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statio_all_tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statio_sys_tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statio_user_tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_stat_all_indexes', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_stat_sys_indexes', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_stat_user_indexes', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statio_all_indexes', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statio_sys_indexes', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statio_user_indexes', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statio_all_sequences', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_wlm_qmr_config', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statio_sys_sequences', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_statio_user_sequences', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_stat_activity', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_stat_database', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_locks', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'pg_test', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_wlm_auto_concurrency', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'information_schema_catalog_name', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'applicable_roles', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'check_constraints', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'column_domain_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_unload_log', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'column_privileges', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'column_udt_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_active_cursors', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_block_reps', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'columns', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_cursor_configuration', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'constraint_column_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_interleaved_counts', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'constraint_table_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_query_metrics', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_query_metrics', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'domain_constraints', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_wlm_rule_action', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'domain_udt_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_startup_recovery_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'domains', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'enabled_roles', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_analyze', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'key_column_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_analyze_compression', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'parameters', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_nestloop', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'referential_constraints', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_parse', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'role_column_grants', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'role_routine_grants', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_project', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'role_table_grants', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_query', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'role_usage_grants', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'routine_privileges', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_return', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'routines', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_save', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'schemata', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_scan', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_sort', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'sql_features', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_query_stats', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'sql_implementation_info', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_hashjoin', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_hash', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'sql_languages', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_insert', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'sql_packages', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_metadata_step', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_unique', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'sql_sizing', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_limit', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_mergejoin', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'sql_sizing_profiles', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_merge', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'table_constraints', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'table_privileges', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'tables', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_pg_wal_length', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'triggered_update_columns', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'triggers', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'usage_privileges', 'VIEW', None, None, None, None, None),
#  ('dwh', 'information_schema', 'view_column_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_aggr', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'view_table_usage', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_bcast', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'views', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_delete', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'data_type_privileges', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_dist', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'information_schema', 'element_types', 'VIEW', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_commit_stats', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_connection_log', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_userlog', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_alert_event_log', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_wlm_classification_config', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_ddltext', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_rpc', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_error', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_explain', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_window', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_file_scan', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_load_commits', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_loaderror_detail', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_wlm_query_queue_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_load_errors', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_wlm_query_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_load_trace', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_wlm_query_task_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_plan_info', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_querytext', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_wlm_service_class_config', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_replacements', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_wlm_service_class_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_s3client', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_s3client_error', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_disk_extents', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_sshclient_error', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_sessions', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_stream_segs', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_tr_conflict', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_udf_compile_error', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_undone', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_utilitytext', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_vacuum_detail', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_vacuum', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_leader_snapshot', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_warning', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_wlm_error', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_wlm_query', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_restarted_sessions', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stl_disk_full_diag', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_blocklist', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_exec_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_inflight', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_load_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_locks', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_partitions', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_process_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_proc_stat', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_recents', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_sessions', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_session_state', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_slices', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_table_partitions', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_table_partition_summary', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_table_vacuum_advisor_info', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_tbl_perm', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_tbl_trans', 'BASE TABLE', None, None, None, None, None),
#  ('dwh', 'pg_catalog', 'stv_underrepped_blocks', 'BASE TABLE', None, None, None, None, None)]

# %% [markdown]
# ## STEP 5: Clean up your resources

# %% [markdown]
# <b><font color='red'>DO NOT RUN THIS UNLESS YOU ARE SURE <br/>
#     We will be using these resources in the next exercises</span></b>

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
redshift.delete_cluster( ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,  SkipFinalClusterSnapshot=True)
#### CAREFUL!!
# Out:
# {'Cluster': {'AllowVersionUpgrade': True,
#   'AutomatedSnapshotRetentionPeriod': 1,
#   'AvailabilityZone': 'us-west-2b',
#   'ClusterCreateTime': datetime.datetime(2019, 2, 16, 6, 21, 30, 630000, tzinfo=tzutc()),
#   'ClusterIdentifier': 'dwhcluster',
#   'ClusterParameterGroups': [{'ParameterApplyStatus': 'in-sync',
#     'ParameterGroupName': 'default.redshift-1.0'}],
#   'ClusterSecurityGroups': [],
#   'ClusterStatus': 'deleting',
#   'ClusterSubnetGroupName': 'default',
#   'ClusterVersion': '1.0',
#   'DBName': 'dwh',
#   'Encrypted': False,
#   'Endpoint': {'Address': 'dwhcluster.csmamz5zxmle.us-west-2.redshift.amazonaws.com',
#    'Port': 5439},
#   'EnhancedVpcRouting': False,
#   'IamRoles': [{'ApplyStatus': 'in-sync',
#     'IamRoleArn': 'arn:aws:iam::988332130976:role/dwhRole'}],
#   'MasterUsername': 'dwhuser',
#   'NodeType': 'dc2.large',
#   'NumberOfNodes': 4,
#   'PendingModifiedValues': {},
#   'PreferredMaintenanceWindow': 'fri:10:30-fri:11:00',
#   'PubliclyAccessible': True,
#   'Tags': [],
#   'VpcId': 'vpc-54d40a2c',
#   'VpcSecurityGroups': []},
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '2041',
#    'content-type': 'text/xml',
#    'date': 'Sat, 16 Feb 2019 07:13:32 GMT',
#    'x-amzn-requestid': '5e58b2d8-31ba-11e9-b19b-0945d449b0a9'},
#   'HTTPStatusCode': 200,
#   'RequestId': '5e58b2d8-31ba-11e9-b19b-0945d449b0a9',
#   'RetryAttempts': 0}}

# %% [markdown]
# - run this block several times until the cluster really deleted

# %%
{k: v for (k, v) in describe_dict.items() if k in metadata_of_interest}
# Out:
# {'ClusterIdentifier': 'dwhcluster',
#  'NodeType': 'dc2.large',
#  'ClusterStatus': 'available',
#  'MasterUsername': 'dwhuser',
#  'DBName': 'dwh',
#  'Endpoint': {'Address': 'dwhcluster.chytho4frjsg.us-west-1.redshift.amazonaws.com',
#   'Port': 5439},
#  'VpcId': 'vpc-efc5f788',
#  'NumberOfNodes': 4}

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
iam.detach_role_policy(RoleName=DWH_IAM_ROLE_NAME, PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess")
iam.delete_role(RoleName=DWH_IAM_ROLE_NAME)
#### CAREFUL!!
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'content-length': '200',
#    'content-type': 'text/xml',
#    'date': 'Sat, 16 Feb 2019 07:13:50 GMT',
#    'x-amzn-requestid': '694f8d91-31ba-11e9-9438-d3ce9c613ef8'},
#   'HTTPStatusCode': 200,
#   'RequestId': '694f8d91-31ba-11e9-9438-d3ce9c613ef8',
#   'RetryAttempts': 0}}
